# %%
# Import required libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset (replace with your own dataset path)
credit_data = pd.read_csv('Credit.csv')  # Replace with your dataset

# ------------------------------
# Histogram: Age Distribution
# ------------------------------
plt.figure(figsize=(6, 4))
sns.histplot(credit_data['Age'].dropna(), bins=30, kde=True)  # Correct column name
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.tight_layout()
plt.savefig('credit_age_distribution.png')  # Save histogram to file
plt.show()
